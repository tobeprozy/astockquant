# %% [markdown]
# # 1. install the required packages

# %%
# 1. install the required packages
# !pip install yfinance stable-baselines3 gym numpy pandas matplotlib
# !pip install ta-lib
# !pip install akshare
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: yfinance in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (0.2.50)
# Requirement already satisfied: stable-baselines3 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (2.4.0)
# Requirement already satisfied: gym in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (0.26.2)
# Requirement already satisfied: numpy in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (1.26.4)
# Requirement already satisfied: pandas in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (2.2.3)
# Requirement already satisfied: matplotlib in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (3.9.3)
# Requirement already satisfied: requests>=2.31 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from yfinance) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from yfinance) (3.17.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from yfinance) (1.1)
# Requirement already satisfied: gymnasium<1.1.0,>=0.29.1 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from stable-baselines3) (1.0.0)
# Requirement already satisfied: torch>=1.13 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from stable-baselines3) (2.5.1)
# Requirement already satisfied: cloudpickle in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from stable-baselines3) (3.1.0)
# Requirement already satisfied: importlib_metadata>=4.8.0 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from gym) (8.5.0)
# Requirement already satisfied: gym_notices>=0.0.4 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from gym) (0.0.8)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from pandas) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from matplotlib) (4.55.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from matplotlib) (6.4.5)
# Requirement already satisfied: soupsieve>1.2 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: six>=1.9 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from html5lib>=1.1->yfinance) (1.17.0)
# Requirement already satisfied: webencodings in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: zipp>=3.20 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from importlib_metadata>=4.8.0->gym) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from requests>=2.31->yfinance) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from requests>=2.31->yfinance) (2024.8.30)
# Requirement already satisfied: filelock in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3) (3.16.1)
# Requirement already satisfied: networkx in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3) (3.2.1)
# Requirement already satisfied: jinja2 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3) (3.1.4)
# Requirement already satisfied: fsspec in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from torch>=1.13->stable-baselines3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from sympy==1.13.1->torch>=1.13->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from jinja2->torch>=1.13->stable-baselines3) (3.0.2)
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: ta-lib in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (0.5.1)
# Requirement already satisfied: numpy in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from ta-lib) (1.26.4)
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting akshare
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/15/34/7d2d52c53356efcdc3891b96980d1d2226d8b790e296b0899360eff48a39/akshare-1.15.44-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 50.5 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4>=4.9.1 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from akshare) (4.12.3)
# Requirement already satisfied: lxml>=4.2.1 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from akshare) (5.3.0)
# Requirement already satisfied: pandas>=0.25 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from akshare) (2.2.3)
# Requirement already satisfied: requests>=2.22.0 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from akshare) (2.32.3)
# Requirement already satisfied: html5lib>=1.0.1 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from akshare) (1.1)
# Collecting xlrd>=1.2.0 (from akshare)
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/a6/0c/c2a72d51fe56e08a08acc85d13013558a2d793028ae7385448a6ccdfae64/xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# Requirement already satisfied: urllib3>=1.25.8 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from akshare) (2.2.3)
# Collecting tqdm>=4.43.0 (from akshare)
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/d0/30/dc54f88dd4a2b5dc8a0279bdd7270e735851848b762aeb1c1184ed1f6b14/tqdm-4.67.1-py3-none-any.whl (78 kB)
# Collecting openpyxl>=3.0.3 (from akshare)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/c0/da/977ded879c29cbd04de313843e76868e6e13408a94ed6b987245dc7c8506/openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Collecting jsonpath>=0.82 (from akshare)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/cf/a1/693351acd0a9edca4de9153372a65e75398898ea7f8a5c722ab00f464929/jsonpath-0.82.2.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting tabulate>=0.8.6 (from akshare)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/40/44/4a5f08c96eb108af5cb50b41f76142f0afa346dfa99d5296fe7202a11854/tabulate-0.9.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: decorator>=4.4.2 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from akshare) (5.1.1)
# Collecting py-mini-racer>=0.6.0 (from akshare)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/29/a9/8ce0ca222ef04d602924a1e099be93f5435ca6f3294182a30574d4159ca2/py_mini_racer-0.6.0-py2.py3-none-manylinux1_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 2.5 MB/s eta 0:00:00a 0:00:01m
# Collecting akracer>=0.0.13 (from akracer[py-mini-racer]>=0.0.13; platform_system == "Linux"->akshare)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/15/86/6ef05f0b51a36dbec2b260da7a93ed0096dea32e708e127c5051b875af2d/akracer-0.0.13-py3-none-any.whl (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 1.8 MB/s eta 0:00:00 0:00:01
# WARNING: akracer 0.0.13 does not provide the extra 'py-mini-racer'
# Requirement already satisfied: soupsieve>1.2 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from beautifulsoup4>=4.9.1->akshare) (2.6)
# Requirement already satisfied: six>=1.9 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from html5lib>=1.0.1->akshare) (1.17.0)
# Requirement already satisfied: webencodings in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from html5lib>=1.0.1->akshare) (0.5.1)
# Collecting et-xmlfile (from openpyxl>=3.0.3->akshare)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/c1/8b/5fe2cc11fee489817272089c4203e679c63b570a5aaeb18d852ae3cbba6a/et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: numpy>=1.22.4 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from pandas>=0.25->akshare) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from pandas>=0.25->akshare) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from pandas>=0.25->akshare) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from pandas>=0.25->akshare) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from requests>=2.22.0->akshare) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from requests>=2.22.0->akshare) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages (from requests>=2.22.0->akshare) (2024.8.30)
# Building wheels for collected packages: jsonpath
#   Building wheel for jsonpath (setup.py) ... done
#   Created wheel for jsonpath: filename=jsonpath-0.82.2-py3-none-any.whl size=5615 sha256=8456dcc11f33c7afd5491b78eeddd6f5dab06c264e4f929b871efa57bcac1a5c
#   Stored in directory: /home/zhiyuanzhang/.cache/pip/wheels/17/d0/24/664883c079ea1332a433e9122ecfe741fd0bb0b478ce3527ae
# Successfully built jsonpath
# Installing collected packages: py-mini-racer, jsonpath, xlrd, tqdm, tabulate, et-xmlfile, akracer, openpyxl, akshare
# Successfully installed akracer-0.0.13 akshare-1.15.44 et-xmlfile-2.0.0 jsonpath-0.82.2 openpyxl-3.1.5 py-mini-racer-0.6.0 tabulate-0.9.0 tqdm-4.67.1 xlrd-2.0.1

# %% [markdown]
# # 2. Download the dow jones 30 stocks data

# %%
import yfinance as yf
import pandas as pd
import akshare as ak
# Danh sách các cổ phiếu trong Dow Jones 30
tickers = [
    '512200','159819','588000','512690','512480','159607'
]

columns_mapping = {
    '日期': 'Date',
    '开盘': 'Open',
    '收盘': 'Close',
    '最高': 'High',
    '最低': 'Low',
    '成交量': 'Volume',
    '成交额': 'Turnover',
    '振幅': 'Amplitude',
    '涨跌幅': 'ChangePercent',
    '涨跌额': 'ChangeAmount',
    '换手率': 'TurnoverRate'
}
        
# Lấy dữ liệu lịch sử từ Yahoo Finance và lưu vào dictionary
def get_data(tickers):
    stock_data = {}
    for ticker in tickers:
        df=ak.fund_etf_hist_em(symbol=ticker, period="daily", start_date="20090101", end_date="20241210", adjust="qfq")
        df.rename(columns=columns_mapping, inplace=True)
        print(df)
        stock_data[ticker] = df.iloc[:, :7]
    return stock_data

# Gọi hàm để lấy dữ liệu
stock_data = get_data(tickers)

# Lưu dữ liệu vào file CSV (tuỳ chọn)
for ticker, df in stock_data.items():
    df.to_csv(f'{ticker}.csv', index=False)
# Out:
#             Date   Open  Close   High    Low   Volume     Turnover  Amplitude  \
# 0     2017-09-25  2.743  2.653  2.743  2.653   761246   73084573.0       3.25
# 1     2017-09-26  2.662  2.670  2.687  2.653   208959   19954482.0       1.28
# 2     2017-09-27  2.670  2.689  2.698  2.670    87335    8383671.0       1.05
# 3     2017-09-28  2.667  2.642  2.687  2.639    69401    6628677.0       1.79
# 4     2017-09-29  2.642  2.650  2.670  2.642    89492    8517971.0       1.06
# ...          ...    ...    ...    ...    ...      ...          ...        ...
# 1744  2024-12-04  1.689  1.655  1.695  1.650  1910770  320615629.0       2.66
# 1745  2024-12-05  1.648  1.666  1.667  1.640  1269774  209933157.0       1.63
# 1746  2024-12-06  1.668  1.690  1.704  1.656  1673462  281901769.0       2.88
# 1747  2024-12-09  1.688  1.637  1.688  1.627  2354252  388370528.0       3.61
# 1748  2024-12-10  1.765  1.656  1.765  1.650  3230384  547348128.0       7.03
#
#       ChangePercent  ChangeAmount  TurnoverRate
# 0             -4.15        -0.115          2.39
# 1              0.64         0.017          0.66
# 2              0.71         0.019          0.27
# 3             -1.75        -0.047          0.22
# 4              0.30         0.008          0.28
# ...             ...           ...           ...
# 1744          -2.24        -0.038          6.01
# 1745           0.66         0.011          3.99
# 1746           1.44         0.024          5.26
# 1747          -3.14        -0.053          7.40
# 1748           1.16         0.019         10.15
#
# [1749 rows x 11 columns]
#             Date   Open  Close   High    Low   Volume      Turnover  \
# 0     2020-09-23  0.983  0.984  0.989  0.975  1342281  1.318954e+08
# 1     2020-09-24  0.978  0.959  0.978  0.959   845634  8.167866e+07
# 2     2020-09-25  0.962  0.958  0.968  0.953   406514  3.901509e+07
# 3     2020-09-28  0.958  0.949  0.962  0.948   521557  4.975498e+07
# 4     2020-09-29  0.951  0.964  0.969  0.951   388866  3.747012e+07
# ...          ...    ...    ...    ...    ...      ...           ...
# 1015  2024-12-04  0.910  0.897  0.916  0.893  3664415  3.308469e+08
# 1016  2024-12-05  0.894  0.910  0.915  0.894  4439978  4.032491e+08
# 1017  2024-12-06  0.915  0.921  0.929  0.905  7736419  7.107589e+08
# 1018  2024-12-09  0.922  0.912  0.927  0.902  4799571  4.389852e+08
# 1019  2024-12-10  0.945  0.918  0.949  0.916  7806443  7.259546e+08
#
#       Amplitude  ChangePercent  ChangeAmount  TurnoverRate
# 0          1.43           0.31         0.003          1.55
# 1          1.93          -2.54        -0.025          0.98
# 2          1.56          -0.10        -0.001          0.47
# 3          1.46          -0.94        -0.009          0.60
# 4          1.90           1.58         0.015          0.45
# ...         ...            ...           ...           ...
# 1015       2.53          -1.21        -0.011          4.24
# 1016       2.34           1.45         0.013          5.14
# 1017       2.64           1.21         0.011          8.95
# 1018       2.71          -0.98        -0.009          5.55
# 1019       3.62           0.66         0.006          9.03
#
# [1020 rows x 11 columns]
#            Date   Open  Close   High    Low    Volume      Turnover  \
# 0    2020-11-16  1.556  1.465  1.620  1.451  14453638  2.119241e+09
# 1    2020-11-17  1.460  1.436  1.460  1.430  10806365  1.553722e+09
# 2    2020-11-18  1.435  1.424  1.445  1.422   8631881  1.234789e+09
# 3    2020-11-19  1.424  1.438  1.440  1.412   6854018  9.803946e+08
# 4    2020-11-20  1.436  1.435  1.444  1.431   6010034  8.626239e+08
# ..          ...    ...    ...    ...    ...       ...           ...
# 983  2024-12-04  1.072  1.050  1.075  1.045  45092827  4.782761e+09
# 984  2024-12-05  1.045  1.053  1.058  1.043  30860025  3.243936e+09
# 985  2024-12-06  1.056  1.067  1.077  1.045  55304411  5.883308e+09
# 986  2024-12-09  1.065  1.054  1.069  1.046  41233209  4.356614e+09
# 987  2024-12-10  1.117  1.063  1.117  1.059  74808790  8.094658e+09
#
#      Amplitude  ChangePercent  ChangeAmount  TurnoverRate
# 0        11.74           1.81         0.026          1.50
# 1         2.05          -1.98        -0.029          1.12
# 2         1.60          -0.84        -0.012          0.89
# 3         1.97           0.98         0.014          0.71
# 4         0.90          -0.21        -0.003          0.62
# ..         ...            ...           ...           ...
# 983       2.84          -0.66        -0.007          4.67
# 984       1.43           0.29         0.003          3.20
# 985       3.04           1.33         0.014          5.73
# 986       2.16          -1.22        -0.013          4.27
# 987       5.50           0.85         0.009          7.75
#
# [988 rows x 11 columns]
#             Date   Open  Close   High    Low    Volume      Turnover  \
# 0     2019-05-06  0.122  0.104  0.142  0.104    184843  1.728714e+07
# 1     2019-05-07  0.108  0.126  0.131  0.108    203258  1.923936e+07
# 2     2019-05-08  0.120  0.127  0.138  0.113    219403  2.094618e+07
# 3     2019-05-09  0.119  0.108  0.125  0.101    222401  2.050494e+07
# 4     2019-05-10  0.114  0.134  0.138  0.113    290585  2.767993e+07
# ...          ...    ...    ...    ...    ...       ...           ...
# 1356  2024-12-04  0.637  0.631  0.638  0.630  10161531  6.432818e+08
# 1357  2024-12-05  0.630  0.630  0.632  0.626   8864904  5.577648e+08
# 1358  2024-12-06  0.631  0.636  0.640  0.629  11315059  7.183498e+08
# 1359  2024-12-09  0.635  0.634  0.642  0.631   9321885  5.925647e+08
# 1360  2024-12-10  0.663  0.646  0.670  0.645  27893897  1.835600e+09
#
#       Amplitude  ChangePercent  ChangeAmount  TurnoverRate
# 0         24.84         -32.03        -0.049          0.08
# 1         22.12          21.15         0.022          0.09
# 2         19.84           0.79         0.001          0.09
# 3         18.90         -14.96        -0.019          0.09
# 4         23.15          24.07         0.026          0.12
# ...         ...            ...           ...           ...
# 1356       1.25          -1.10        -0.007          4.32
# 1357       0.95          -0.16        -0.001          3.77
# 1358       1.75           0.95         0.006          4.81
# 1359       1.73          -0.31        -0.002          3.96
# 1360       3.94           1.89         0.012         11.85
#
# [1361 rows x 11 columns]
#             Date   Open  Close   High    Low    Volume      Turnover  \
# 0     2019-06-12  0.497  0.507  0.511  0.495   1346322  1.352732e+08
# 1     2019-06-13  0.505  0.500  0.508  0.497    150306  1.511334e+07
# 2     2019-06-14  0.499  0.483  0.503  0.482     76983  7.600680e+06
# 3     2019-06-17  0.483  0.477  0.485  0.474     50678  4.842825e+06
# 4     2019-06-18  0.479  0.473  0.479  0.470     40390  3.823312e+06
# ...          ...    ...    ...    ...    ...       ...           ...
# 1330  2024-12-04  1.027  1.003  1.038  0.999  22150062  2.258738e+09
# 1331  2024-12-05  0.993  1.002  1.006  0.991  11922700  1.191437e+09
# 1332  2024-12-06  1.002  1.013  1.023  0.990  19114223  1.928754e+09
# 1333  2024-12-09  1.009  0.996  1.013  0.989  14728232  1.470719e+09
# 1334  2024-12-10  1.040  1.006  1.045  1.003  24585806  2.513053e+09
#
#       Amplitude  ChangePercent  ChangeAmount  TurnoverRate
# 0          3.18           0.80         0.004          0.51
# 1          2.17          -1.38        -0.007          0.06
# 2          4.20          -3.40        -0.017          0.03
# 3          2.28          -1.24        -0.006          0.02
# 4          1.89          -0.84        -0.004          0.02
# ...         ...            ...           ...           ...
# 1330       3.90           0.20         0.002          8.32
# 1331       1.50          -0.10        -0.001          4.48
# 1332       3.29           1.10         0.011          7.18
# 1333       2.37          -1.68        -0.017          5.53
# 1334       4.22           1.00         0.010          9.23
#
# [1335 rows x 11 columns]
#            Date   Open  Close   High    Low   Volume      Turnover  Amplitude  \
# 0    2021-12-02  0.977  0.980  0.981  0.956  1078630  1.050153e+08       2.55
# 1    2021-12-03  0.976  0.964  0.980  0.959   796786  7.702600e+07       2.14
# 2    2021-12-06  0.917  0.917  0.933  0.910   930502  8.587753e+07       2.39
# 3    2021-12-07  0.942  0.956  0.957  0.934   982536  9.264897e+07       2.51
# 4    2021-12-08  0.973  0.967  0.977  0.962   916310  8.866955e+07       1.57
# ..          ...    ...    ...    ...    ...      ...           ...        ...
# 728  2024-12-04  0.902  0.900  0.908  0.897  3002115  2.709749e+08       1.22
# 729  2024-12-05  0.894  0.889  0.895  0.887  3216685  2.864199e+08       0.89
# 730  2024-12-06  0.893  0.907  0.909  0.889  4321159  3.888572e+08       2.25
# 731  2024-12-09  0.902  0.906  0.913  0.901  2776835  2.513695e+08       1.32
# 732  2024-12-10  0.974  0.941  0.982  0.941  7231633  6.941177e+08       4.53
#
#      ChangePercent  ChangeAmount  TurnoverRate
# 0            -0.20        -0.002          5.22
# 1            -1.63        -0.016          3.86
# 2            -4.88        -0.047          4.50
# 3             4.25         0.039          4.76
# 4             1.15         0.011          4.44
# ..             ...           ...           ...
# 728          -0.33        -0.003         14.53
# 729          -1.22        -0.011         15.57
# 730           2.02         0.018         20.92
# 731          -0.11        -0.001         13.44
# 732           3.86         0.035         35.01
#
# [733 rows x 11 columns]

# %% [markdown]
# # 3. Load the data from the CSV files

# %%
import pandas as pd

# Danh sách các cổ phiếu trong Dow Jones 30
tickers = [
    '512200','159819','588000','512690','512480','159607'
]
# ticker of benchmark
benchmark = '^DJI'

# Get the data from the CSV files
stock_data = {}
for ticker in tickers:
    df = pd.read_csv(f'{ticker}.csv', index_col='Date', parse_dates=True)
    stock_data[ticker] = df


# split the data into training, validation and test sets
training_data_time_range = ('2017-01-01', '2022-12-31')
validation_data_time_range = ('2022-01-01', '2023-12-31')
test_data_time_range = ('2024-01-01', '2024-05-08')

# split the data into training, validation and test sets
training_data = {}
validation_data = {}
test_data = {}

for ticker, df in stock_data.items():
    training_data[ticker] = df.loc[training_data_time_range[0]:training_data_time_range[1]]
    validation_data[ticker] = df.loc[validation_data_time_range[0]:validation_data_time_range[1]]
    test_data[ticker] = df.loc[test_data_time_range[0]:test_data_time_range[1]]

# print shape of training, validation and test data
ticker = '588000'
print(f'Training data shape for {ticker}: {training_data[ticker].shape}')
print(f'Validation data shape for {ticker}: {validation_data[ticker].shape}')
print(f'Test data shape for {ticker}: {test_data[ticker].shape}')

# Display the first 5 rows of the data
stock_data['588000'].head()
# Out:
# Training data shape for 588000: (519, 6)
# Validation data shape for 588000: (484, 6)
# Test data shape for 588000: (81, 6)
#              Open  Close   High    Low    Volume      Turnover
# Date
# 2020-11-16  1.556  1.465  1.620  1.451  14453638  2.119241e+09
# 2020-11-17  1.460  1.436  1.460  1.430  10806365  1.553722e+09
# 2020-11-18  1.435  1.424  1.445  1.422   8631881  1.234789e+09
# 2020-11-19  1.424  1.438  1.440  1.412   6854018  9.803946e+08
# 2020-11-20  1.436  1.435  1.444  1.431   6010034  8.626239e+08

# %% [markdown]
# # 4. Add technical indicators to the data

# %% [markdown]
# Function to add technical indicators to the data:

# %%
import pandas as pd
import numpy as np

def add_technical_indicators(df):
    # calculate RSI 14 
    delta = df['Close'].diff()
    up = delta.where(delta > 0, 0)
    down = -delta.where(delta < 0, 0)
    rs = up.rolling(window=14).mean() / down.rolling(window=14).mean()
    df['RSI'] = 100 - (100 / (1 + rs))

    # Tính toán EMA 12 và 26 kỳ cho MACD
    df['EMA12'] = df['Close'].ewm(span=12, adjust=False).mean()
    df['EMA26'] = df['Close'].ewm(span=26, adjust=False).mean()
    df['MACD'] = df['EMA12'] - df['EMA26']
    df['Signal'] = df['MACD'].ewm(span=9, adjust=False).mean()
    
    # Tính toán RSI 14 kỳ
    delta = df['Close'].diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=14).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=14).mean()
    rs = gain / loss
    df['RSI'] = 100 - (100 / (1 + rs))
    
    # Tính toán CCI 20 kỳ
    tp = (df['High'] + df['Low'] + df['Close']) / 3
    sma_tp = tp.rolling(window=20).mean()
    mean_dev = tp.rolling(window=20).apply(lambda x: np.mean(np.abs(x - x.mean())))
    df['CCI'] = (tp - sma_tp) / (0.015 * mean_dev)
    
    # Tính toán ADX 14 kỳ
    high_diff = df['High'].diff()
    low_diff = df['Low'].diff()
    df['+DM'] = np.where((high_diff > low_diff) & (high_diff > 0), high_diff, 0)
    df['-DM'] = np.where((low_diff > high_diff) & (low_diff > 0), low_diff, 0)
    tr = pd.concat([df['High'] - df['Low'], np.abs(df['High'] - df['Close'].shift(1)), np.abs(df['Low'] - df['Close'].shift(1))], axis=1).max(axis=1)
    atr = tr.ewm(span=14, adjust=False).mean()
    df['+DI'] = 100 * (df['+DM'].ewm(span=14, adjust=False).mean() / atr)
    df['-DI'] = 100 * (df['-DM'].ewm(span=14, adjust=False).mean() / atr)
    dx = 100 * np.abs(df['+DI'] - df['-DI']) / (df['+DI'] + df['-DI'])
    df['ADX'] = dx.ewm(span=14, adjust=False).mean()

    # drop NaN values
    df.dropna(inplace=True)

    # keep Open, High, Low, Close, Volume, MACD, Signal, RSI, CCI, ADX
    df = df[['Open', 'High', 'Low', 'Close', 'Volume', 'MACD', 'Signal', 'RSI', 'CCI', 'ADX']]

    return df

# %% [markdown]
# add technical indicators to the data

# %%
# add technical indicators to the training data for each stock
for ticker, df in training_data.items():
    training_data[ticker] = add_technical_indicators(df)

# add technical indicators to the validation data for each stock
for ticker, df in validation_data.items():
    validation_data[ticker] = add_technical_indicators(df)

# add technical indicators to the test data for each stock
for ticker, df in test_data.items():
    test_data[ticker] = add_technical_indicators(df)

# print the first 5 rows of the data
print('Shape of training data for AAPL:', training_data['588000'].shape)
print('Shape of validation data for AAPL:', validation_data['588000'].shape)
print('Shape of test data for AAPL:', test_data['588000'].shape)

training_data['588000']
# Out:
# Shape of training data for AAPL: (462, 10)
# Shape of validation data for AAPL: (427, 10)
# Shape of test data for AAPL: (24, 10)
#              Open   High    Low  Close    Volume      MACD    Signal  \
# Date
# 2021-02-04  1.447  1.453  1.410  1.435   8205920  0.004660  0.014286
# 2021-02-05  1.434  1.447  1.413  1.414   5856997 -0.000567  0.011315
# 2021-02-08  1.413  1.435  1.409  1.425   4334000 -0.003778  0.008296
# 2021-02-09  1.426  1.476  1.424  1.472   6036093 -0.002502  0.006137
# 2021-02-10  1.470  1.482  1.451  1.478   5868850 -0.000995  0.004710
# ...           ...    ...    ...    ...       ...       ...       ...
# 2022-12-26  0.961  0.993  0.960  0.992  20697596 -0.020555 -0.014556
# 2022-12-27  0.994  1.007  0.987  1.004  17568542 -0.018905 -0.015425
# 2022-12-28  0.999  1.004  0.996  0.998  11521170 -0.017875 -0.015915
# 2022-12-29  0.994  1.011  0.993  1.004  15721922 -0.016386 -0.016010
# 2022-12-30  1.005  1.011  1.000  1.003  11055558 -0.015112 -0.015830
#
#                   RSI         CCI        ADX
# Date
# 2021-02-04  38.461538 -110.409866  21.615493
# 2021-02-05  26.068376 -129.205479  18.758339
# 2021-02-08  34.123223 -128.683834  16.282139
# 2021-02-09  38.495575  -58.429858  21.438288
# 2021-02-10  39.565217  -33.219048  19.827729
# ...               ...         ...        ...
# 2022-12-26  29.496403 -115.132803  29.094686
# 2022-12-27  35.810811  -60.868091  26.788697
# 2022-12-28  34.868421  -54.311774  26.773934
# 2022-12-29  37.341772  -40.269591  24.540370
# 2022-12-30  35.483871  -29.988926  24.184926
#
# [462 rows x 10 columns]

# %% [markdown]
# # 5. Create Trading Environment

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import pandas as pd

class StockTradingEnv(gym.Env):
    metadata = {'render_modes': ['human']}
    
    def __init__(self, stock_data, transaction_cost_percent=0.005):
        super(StockTradingEnv, self).__init__()
        
        # Remove any empty DataFrames
        self.stock_data = {ticker: df for ticker, df in stock_data.items() if not df.empty}
        self.tickers = list(self.stock_data.keys())
        
        if not self.tickers:
            raise ValueError("All provided stock data is empty")
        
        # Calculate the size of one stock's data
        sample_df = next(iter(self.stock_data.values()))
        self.n_features = len(sample_df.columns)
        
        # Define action and observation space
        self.action_space = spaces.Box(low=-1, high=1, shape=(len(self.tickers),), dtype=np.float32)
        
        # Observation space: price data for each stock + balance + shares held + net worth + max net worth + current step
        self.obs_shape = self.n_features * len(self.tickers) + 2 + len(self.tickers) + 2
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(self.obs_shape,), dtype=np.float32)
        
        # Initialize account balance
        self.initial_balance = 1000
        self.balance = self.initial_balance
        self.net_worth = self.initial_balance
        self.max_net_worth = self.initial_balance
        self.shares_held = {ticker: 0 for ticker in self.tickers}
        self.total_shares_sold = {ticker: 0 for ticker in self.tickers}
        self.total_sales_value = {ticker: 0 for ticker in self.tickers}
        
        # Set the current step
        self.current_step = 0
        
        # Calculate the minimum length of data across all stocks
        self.max_steps = max(0, min(len(df) for df in self.stock_data.values()) - 1)

        # Transaction cost
        self.transaction_cost_percent = transaction_cost_percent
    
    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.balance = self.initial_balance
        self.net_worth = self.initial_balance
        self.max_net_worth = self.initial_balance
        self.shares_held = {ticker: 0 for ticker in self.tickers}
        self.total_shares_sold = {ticker: 0 for ticker in self.tickers}
        self.total_sales_value = {ticker: 0 for ticker in self.tickers}
        self.current_step = 0
        return self._next_observation(), {}
    
    def _next_observation(self):
        # initialize the frame
        frame = np.zeros(self.obs_shape)
        
        # Add stock data for each ticker
        idx = 0
        # Loop through each ticker
        for ticker in self.tickers:
            # Get the DataFrame for the current ticker
            df = self.stock_data[ticker]
            # If the current step is less than the length of the DataFrame, add the price data for the current step
            if self.current_step < len(df):
                frame[idx:idx+self.n_features] = df.iloc[self.current_step].values
            # Otherwise, add the last price data available
            elif len(df) > 0:
                frame[idx:idx+self.n_features] = df.iloc[-1].values
            # Move the index to the next ticker
            idx += self.n_features

        # Add balance, shares held, net worth, max net worth, and current step
        frame[-4-len(self.tickers)] = self.balance # Balance
        frame[-3-len(self.tickers):-3] = [self.shares_held[ticker] for ticker in self.tickers] # Shares held
        frame[-3] = self.net_worth # Net worth
        frame[-2] = self.max_net_worth # Max net worth
        frame[-1] = self.current_step # Current step
        
        return frame
    
    def step(self, actions):
        # update the current step
        self.current_step += 1
        
        # check if we have reached the maximum number of steps
        if self.current_step > self.max_steps:
            return self._next_observation(), 0, True, False, {}
        
        current_prices = {}
        # Loop through each ticker and perform the action
        for i, ticker in enumerate(self.tickers):
            # Get the current price of the stock
            current_prices[ticker] = self.stock_data[ticker].iloc[self.current_step]['Close']
            # get the action for the current ticker
            action = actions[i]
            
            if action > 0:  # Buy
                # Calculate the number of shares to buy
                shares_to_buy = int(self.balance * action / current_prices[ticker])
                # Calculate the cost of the shares
                cost = shares_to_buy * current_prices[ticker]
                # Transaction cost
                transaction_cost = cost * self.transaction_cost_percent
                # Update the balance and shares held
                self.balance -= (cost + transaction_cost)
                # Update the total shares sold
                self.shares_held[ticker] += shares_to_buy

            elif action < 0:  # Sell
                # Calculate the number of shares to sell
                shares_to_sell = int(self.shares_held[ticker] * abs(action))
                # Calculate the sale value
                sale = shares_to_sell * current_prices[ticker]
                # Transaction cost
                transaction_cost = sale * self.transaction_cost_percent
                # Update the balance and shares held
                self.balance += (sale - transaction_cost)
                # Update the total shares sold
                self.shares_held[ticker] -= shares_to_sell
                # Update the shares sold
                self.total_shares_sold[ticker] += shares_to_sell
                # Update the total sales value
                self.total_sales_value[ticker] += sale
        
        # Calculate the net worth
        self.net_worth = self.balance + sum(self.shares_held[ticker] * current_prices[ticker] for ticker in self.tickers)
        # Update the max net worth
        self.max_net_worth = max(self.net_worth, self.max_net_worth)
        # Calculate the reward
        reward = self.net_worth - self.initial_balance
        # Check if the episode is done
        done = self.net_worth <= 0 or self.current_step >= self.max_steps
        
        obs = self._next_observation()
        return obs, reward, done, False, {}
    
    def render(self, mode='human'):
        # Print the current step, balance, shares held, net worth, and profit
        profit = self.net_worth - self.initial_balance
        print(f'Step: {self.current_step}')
        print(f'Balance: {self.balance:.2f}')
        for ticker in self.tickers:
            print(f'{ticker} Shares held: {self.shares_held[ticker]}')
        print(f'Net worth: {self.net_worth:.2f}')
        print(f'Profit: {profit:.2f}')

    def close(self):
        pass

def update_stock_data(self, new_stock_data, transaction_cost_percent=None):
    """
    Update the environment with new stock data.

    Parameters:
    new_stock_data (dict): Dictionary containing new stock data,
                           with keys as stock tickers and values as DataFrames.
    """
    # Remove empty DataFrames
    self.stock_data = {ticker: df for ticker, df in new_stock_data.items() if not df.empty}
    self.tickers = list(self.stock_data.keys())

    if not self.tickers:
        raise ValueError("All new stock data are empty")

    # Update the number of features if needed
    sample_df = next(iter(self.stock_data.values()))
    self.n_features = len(sample_df.columns)

    # Update observation space
    self.obs_shape = self.n_features * len(self.tickers) + 2 + len(self.tickers) + 2
    self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(self.obs_shape,), dtype=np.float32)

    # Update maximum steps
    self.max_steps = max(0, min(len(df) for df in self.stock_data.values()) - 1)

    # Update transaction cost if provided
    if transaction_cost_percent is not None:
        self.transaction_cost_percent = transaction_cost_percent

    # Reset the environment
    self.reset()

    print(f"The environment has been updated with {len(self.tickers)} new stocks.")

# %% [markdown]
# # 6. Training Model - Ensemble + PPO + A2C + DDPG + SAC + TD3

# %% [markdown]
# ## Define Functions

# %% [markdown]
# Define Agents ( Ensemble + PPO + A2C + DDPG)

# %%
from stable_baselines3 import PPO, A2C, DDPG, SAC, TD3
from stable_baselines3.common.vec_env import DummyVecEnv

# Define Ensemble Agent
class EnsembleAgent:
    def __init__(self, ppo_model, a2c_model, ddpg_model, sac_model, td3_model):
        self.ppo_model = ppo_model
        self.a2c_model = a2c_model
        self.ddpg_model = ddpg_model
        self.sac_model = sac_model
        self.td3_model = td3_model
    
    def predict(self, obs):
        ppo_action, _ = self.ppo_model.predict(obs)
        a2c_action, _ = self.a2c_model.predict(obs)
        ddpg_action, _ = self.ddpg_model.predict(obs)
        sac_action, _ = self.sac_model.predict(obs)
        td3_action, _ = self.td3_model.predict(obs)
        
        # Average the actions
        ensemble_action = np.mean([ppo_action, a2c_action, ddpg_action, sac_action, td3_action], axis=0)
        return ensemble_action
    
# Define PPO Agent
class PPOAgent:
    def __init__(self, env, total_timesteps):
        self.model = PPO("MlpPolicy", env, verbose=1)
        self.model.learn(total_timesteps=total_timesteps)
    
    def predict(self, obs):
        action, _ = self.model.predict(obs)
        return action
    
# Define A2C Agent
class A2CAgent:
    def __init__(self, env, total_timesteps):
        self.model = A2C("MlpPolicy", env, verbose=1)
        self.model.learn(total_timesteps=total_timesteps)
    
    def predict(self, obs):
        action, _ = self.model.predict(obs)
        return action
    
# Define DDPG Agent
class DDPGAgent:
    def __init__(self, env, total_timesteps):
        self.model = DDPG("MlpPolicy", env, verbose=1)
        self.model.learn(total_timesteps=total_timesteps)
    
    def predict(self, obs):
        action, _ = self.model.predict(obs)
        return action
     
# Define SAC Agent
class SACAgent:
    def __init__(self, env, total_timesteps):
        self.model = SAC("MlpPolicy", env, verbose=1)
        self.model.learn(total_timesteps=total_timesteps)
    
    def predict(self, obs):
        action, _ = self.model.predict(obs)
        return action
    
# Define TD3 Agent
class TD3Agent:
    def __init__(self, env, total_timesteps):
        self.model = TD3("MlpPolicy", env, verbose=1)
        self.model.learn(total_timesteps=total_timesteps)
    
    def predict(self, obs):
        action, _ = self.model.predict(obs)
        return action

# %% [markdown]
# Function to Create Environment + Train 6 Agents: PPO, A2C, DDPG, SAC, TD3 and Ensemble ( PPO + A2C + DDPG + SAC + TD3)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Function to create the environment and train the agents
def create_env_and_train_agents(data, total_timesteps):
    # Create the environment using DummyVecEnv with training data
    env = DummyVecEnv([lambda: StockTradingEnv(data)])

    # Train PPO Agent
    ppo_agent = PPOAgent(env, total_timesteps)

    # Train A2C Agent
    a2c_agent = A2CAgent(env, total_timesteps)

    # Train DDPG Agent
    ddpg_agent = DDPGAgent(env, total_timesteps)

    # Train SAC Agent
    sac_agent = SACAgent(env, total_timesteps)

    # Train TD3 Agent
    td3_agent = TD3Agent(env, total_timesteps)

    # Train the ensemble agent
    ensemble_agent = EnsembleAgent(ppo_agent.model, a2c_agent.model, ddpg_agent.model, sac_agent.model, td3_agent.model)

    return env, ppo_agent, a2c_agent, ddpg_agent, sac_agent, td3_agent, ensemble_agent

# %% [markdown]
# Function to visualiza Portfolio changes, Portfolio Net Worth and Multiple Portfolio Net Worth

# %%
import matplotlib.pyplot as plt

# Function to visualize portfolio changes
def visualize_portfolio(steps, balances, net_worths, shares_held, tickers, show_balance=True, show_net_worth=True, show_shares_held=True):
    fig, axs = plt.subplots(3, figsize=(12, 18))

    # Plot the balance
    if show_balance:
        axs[0].plot(steps, balances, label='Balance')
        axs[0].set_title('Balance Over Time')
        axs[0].set_xlabel('Steps')
        axs[0].set_ylabel('Balance')
        axs[0].legend()

    # Plot the net worth
    if show_net_worth:
        axs[1].plot(steps, net_worths, label='Net Worth', color='orange')
        axs[1].set_title('Net Worth Over Time')
        axs[1].set_xlabel('Steps')
        axs[1].set_ylabel('Net Worth')
        axs[1].legend()

    # Plot the shares held
    if show_shares_held:
        for ticker in tickers:
            axs[2].plot(steps, shares_held[ticker], label=f'Shares Held: {ticker}')
        axs[2].set_title('Shares Held Over Time')
        axs[2].set_xlabel('Steps')
        axs[2].set_ylabel('Shares Held')
        axs[2].legend()

    plt.tight_layout()
    plt.show()

# function to visualize the portfolio net worth
def visualize_portfolio_net_worth(steps, net_worths):
    plt.figure(figsize=(12, 6))
    plt.plot(steps, net_worths, label='Net Worth', color='orange')
    plt.title('Net Worth Over Time')
    plt.xlabel('Steps')
    plt.ylabel('Net Worth')
    plt.legend()
    plt.show()

# function to visualize the multiple portfolio net worths ( same chart )
def visualize_multiple_portfolio_net_worth(steps, net_worths_list, labels):
    plt.figure(figsize=(12, 6))
    for i, net_worths in enumerate(net_worths_list):
        plt.plot(steps, net_worths, label=labels[i])
    plt.title('Net Worth Over Time')
    plt.xlabel('Steps')
    plt.ylabel('Net Worth')
    plt.legend()
    plt.show()

# %% [markdown]
# Function Visualize the Agent's performance ( Ensemble )

# %%
def test_agent(env, agent, stock_data, n_tests=1000, visualize=False):
    """
    Test a single agent and track performance metrics, with an option to visualize the results.

    Parameters:
    - env: The trading environment.
    - agent: The agent to be tested.
    - stock_data: Data for the stocks in the environment.
    - n_tests: Number of tests to run (default: 1000).
    - visualize: Boolean flag to enable or disable visualization (default: False).

    Returns:
    - A dictionary containing steps, balances, net worths, and shares held.
    """
    # Initialize metrics tracking
    metrics = {
        'steps': [],
        'balances': [],
        'net_worths': [],
        'shares_held': {ticker: [] for ticker in stock_data.keys()}
    }

    # Reset the environment before starting the tests
    obs = env.reset()

    for i in range(n_tests):
        metrics['steps'].append(i)
        action = agent.predict(obs)
        obs, rewards, dones, infos = env.step(action)
        if visualize:
            env.render()

        # Track metrics
        metrics['balances'].append(env.get_attr('balance')[0])
        metrics['net_worths'].append(env.get_attr('net_worth')[0])
        env_shares_held = env.get_attr('shares_held')[0]

        # Update shares held for each ticker
        for ticker in stock_data.keys():
            if ticker in env_shares_held:
                metrics['shares_held'][ticker].append(env_shares_held[ticker])
            else:
                metrics['shares_held'][ticker].append(0)  # Append 0 if ticker is not found

        if dones:
            obs = env.reset()
            
    return metrics

# %% [markdown]
# Function to Test and Visualize the Agent's performance ( Ensemble Agent )

# %%
def test_and_visualize_agents(env, agents, training_data, n_tests=1000):
    metrics = {}
    for agent_name, agent in agents.items():
        print(f"Testing {agent_name}...")
        metrics[agent_name] = test_agent(env, agent, training_data, n_tests=n_tests, visualize=True)
        print(f"Done testing {agent_name}!")
    
    print('-'*50)
    print('All agents tested!')
    print('-'*50)

    # Extract net worths for visualization
    net_worths = [metrics[agent_name]['net_worths'] for agent_name in agents.keys()]
    steps = next(iter(metrics.values()))['steps']  # Assuming all agents have the same step count for simplicity

    # Visualize the performance metrics of multiple agents
    visualize_multiple_portfolio_net_worth(steps, net_worths, list(agents.keys()))

# %% [markdown]
# Function to compare the performance of the 4 Agents : Returns, Standard Deviation, Sharpe Ratio

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def compare_and_plot_agents(agents_metrics, labels, risk_free_rate=0.0):
    # Function to compare returns, standard deviation, and sharpe ratio of agents
    def compare_agents(agents_metrics, labels):
        returns = []
        stds = []
        sharpe_ratios = []

        for metrics in agents_metrics:
            net_worths = metrics['net_worths']
            # Calculate daily returns
            daily_returns = np.diff(net_worths) / net_worths[:-1]
            avg_return = np.mean(daily_returns)
            std_return = np.std(daily_returns)
            sharpe_ratio = (avg_return - risk_free_rate) / std_return

            returns.append(avg_return)
            stds.append(std_return)
            sharpe_ratios.append(sharpe_ratio)

        df = pd.DataFrame({
            'Agent': labels,
            'Return': returns,
            'Standard Deviation': stds,
            'Sharpe Ratio': sharpe_ratios
        })

        return df

    # Compare agents
    df = compare_agents(agents_metrics, labels)
    # Sort the dataframe by sharpe ratio
    df_sorted = df.sort_values(by='Sharpe Ratio', ascending=False)

    # Display the dataframe
    display(df_sorted)

    # Plot bar chart for sharpe ratio
    plt.figure(figsize=(12, 6))
    plt.bar(df_sorted['Agent'], df_sorted['Sharpe Ratio'])
    plt.title('Sharpe Ratio Comparison')
    plt.xlabel('Agent')
    plt.ylabel('Sharpe Ratio')
    plt.show()

# %% [markdown]
# ## Run

# %%
# 1. Create the environment and train the agents
total_timesteps = 10000
env, ppo_agent, a2c_agent, ddpg_agent, ensemble_agent, sac_agent, td3_agent = create_env_and_train_agents(training_data, total_timesteps)

# 2. Test & visualize the agents
n_tests = 1000
agents = {
    'PPO Agent': ppo_agent,
    'A2C Agent': a2c_agent,
    'DDPG Agent': ddpg_agent,
    'Ensemble Agent': ensemble_agent, 
    'SAC Agent': sac_agent,
    'TD3 Agent': td3_agent
}
test_and_visualize_agents(env, agents, training_data, n_tests=n_tests)
# Out:
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 766  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 620         |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.005845677 |
# |    clip_fraction        | 0.036       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.51       |
# |    explained_variance   | 6.02e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.69e+06    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00672    |
# |    std                  | 1           |
# |    value_loss           | 1.45e+07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 592          |
# |    iterations           | 3            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0057839886 |
# |    clip_fraction        | 0.0293       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.51        |
# |    explained_variance   | 2.64e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.22e+06     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00583     |
# |    std                  | 1            |
# |    value_loss           | 1.59e+07     |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 577        |
# |    iterations           | 4          |
# |    time_elapsed         | 14         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.00411113 |
# |    clip_fraction        | 0.0166     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.51      |
# |    explained_variance   | 7.03e-06   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.08e+06   |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.00446   |
# |    std                  | 0.999      |
# |    value_loss           | 1.86e+07   |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 575          |
# |    iterations           | 5            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0049123475 |
# |    clip_fraction        | 0.0187       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.51        |
# |    explained_variance   | 4.17e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.53e+06     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0036      |
# |    std                  | 0.999        |
# |    value_loss           | 1.03e+07     |
# ------------------------------------------
# Using cpu device
# -------------------------------------
# | time/                 |           |
# |    fps                | 350       |
# |    iterations         | 100       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -8.49     |
# |    explained_variance | -0.00022  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | -2.01e+03 |
# |    std                | 0.997     |
# |    value_loss         | 1.1e+05   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 338       |
# |    iterations         | 200       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -8.51     |
# |    explained_variance | -1.41e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | -1.28e+03 |
# |    std                | 1         |
# |    value_loss         | 3.8e+04   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 322      |
# |    iterations         | 300      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -8.51    |
# |    explained_variance | 6.29e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -6.6e+03 |
# |    std                | 1        |
# |    value_loss         | 8.74e+05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 308       |
# |    iterations         | 400       |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -8.53     |
# |    explained_variance | -0.000255 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | -2.73e+03 |
# |    std                | 1         |
# |    value_loss         | 1.27e+05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 315      |
# |    iterations         | 500      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -8.52    |
# |    explained_variance | 0.000299 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -34.4    |
# |    std                | 1        |
# |    value_loss         | 80.8     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 311       |
# |    iterations         | 600       |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -8.5      |
# |    explained_variance | 0.000596  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | -2.77e+03 |
# |    std                | 0.998     |
# |    value_loss         | 1.58e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 313       |
# |    iterations         | 700       |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -8.5      |
# |    explained_variance | -0.000102 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -3.87e+03 |
# |    std                | 0.998     |
# |    value_loss         | 2.14e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 314       |
# |    iterations         | 800       |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -8.51     |
# |    explained_variance | -2.98e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | -7.2e+03  |
# |    std                | 1         |
# |    value_loss         | 8.79e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 311       |
# |    iterations         | 900       |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -8.52     |
# |    explained_variance | -4.23e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | -904      |
# |    std                | 1         |
# |    value_loss         | 1.6e+04   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 315      |
# |    iterations         | 1000     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -8.5     |
# |    explained_variance | -0.00117 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 1.15e+03 |
# |    std                | 0.998    |
# |    value_loss         | 2.26e+04 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 315       |
# |    iterations         | 1100      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -8.47     |
# |    explained_variance | 0.0189    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -2.88e+03 |
# |    std                | 0.993     |
# |    value_loss         | 1.12e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 315       |
# |    iterations         | 1200      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -8.48     |
# |    explained_variance | 0.00856   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | -4.89e+03 |
# |    std                | 0.995     |
# |    value_loss         | 4.28e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 319       |
# |    iterations         | 1300      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -8.49     |
# |    explained_variance | -0.0013   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | -5.34e+03 |
# |    std                | 0.996     |
# |    value_loss         | 3.63e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 318       |
# |    iterations         | 1400      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -8.5      |
# |    explained_variance | 0.0022    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | -1.13e+03 |
# |    std                | 0.997     |
# |    value_loss         | 2.15e+04  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 317       |
# |    iterations         | 1500      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -8.48     |
# |    explained_variance | 0.00321   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | -1.28e+03 |
# |    std                | 0.994     |
# |    value_loss         | 2.88e+04  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 315       |
# |    iterations         | 1600      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -8.48     |
# |    explained_variance | -0.00634  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | -2.07e+03 |
# |    std                | 0.995     |
# |    value_loss         | 8.44e+04  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 315       |
# |    iterations         | 1700      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -8.49     |
# |    explained_variance | -0.000253 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | -3.72e+03 |
# |    std                | 0.997     |
# |    value_loss         | 2.49e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 318       |
# |    iterations         | 1800      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -8.52     |
# |    explained_variance | -9.19e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | -9.63e+03 |
# |    std                | 1         |
# |    value_loss         | 2e+06     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 320      |
# |    iterations         | 1900     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -8.52    |
# |    explained_variance | 8.82e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 4.24e+03 |
# |    std                | 1        |
# |    value_loss         | 2.56e+05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 318       |
# |    iterations         | 2000      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -8.55     |
# |    explained_variance | 4.39e-05  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | -4.29e+03 |
# |    std                | 1.01      |
# |    value_loss         | 3.01e+05  |
# -------------------------------------
# Using cpu device
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 64       |
# |    time_elapsed    | 13       |
# |    total_timesteps | 900      |
# | train/             |          |
# |    actor_loss      | 1.38e+05 |
# |    critic_loss     | 3.9e+08  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 799      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 61       |
# |    time_elapsed    | 29       |
# |    total_timesteps | 1800     |
# | train/             |          |
# |    actor_loss      | 1.19e+05 |
# |    critic_loss     | 2.51e+08 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1699     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 60       |
# |    time_elapsed    | 44       |
# |    total_timesteps | 2700     |
# | train/             |          |
# |    actor_loss      | 1.19e+05 |
# |    critic_loss     | 1.3e+08  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2599     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 60       |
# |    time_elapsed    | 59       |
# |    total_timesteps | 3600     |
# | train/             |          |
# |    actor_loss      | 1.11e+05 |
# |    critic_loss     | 1.4e+08  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3499     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 59       |
# |    time_elapsed    | 75       |
# |    total_timesteps | 4500     |
# | train/             |          |
# |    actor_loss      | 1.02e+05 |
# |    critic_loss     | 1.22e+08 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4399     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 59       |
# |    time_elapsed    | 90       |
# |    total_timesteps | 5400     |
# | train/             |          |
# |    actor_loss      | 9.76e+04 |
# |    critic_loss     | 9.78e+07 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5299     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 59       |
# |    time_elapsed    | 106      |
# |    total_timesteps | 6300     |
# | train/             |          |
# |    actor_loss      | 9.14e+04 |
# |    critic_loss     | 3.66e+07 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6199     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 58       |
# |    time_elapsed    | 122      |
# |    total_timesteps | 7200     |
# | train/             |          |
# |    actor_loss      | 9.03e+04 |
# |    critic_loss     | 2.98e+07 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7099     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 57       |
# |    time_elapsed    | 142      |
# |    total_timesteps | 8100     |
# | train/             |          |
# |    actor_loss      | 7.96e+04 |
# |    critic_loss     | 2.29e+07 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7999     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 55       |
# |    time_elapsed    | 161      |
# |    total_timesteps | 9000     |
# | train/             |          |
# |    actor_loss      | 7.87e+04 |
# |    critic_loss     | 5.46e+07 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8899     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 54       |
# |    time_elapsed    | 180      |
# |    total_timesteps | 9900     |
# | train/             |          |
# |    actor_loss      | 7.38e+04 |
# |    critic_loss     | 8.36e+06 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9799     |
# ---------------------------------
# Using cpu device
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 40        |
# |    time_elapsed    | 22        |
# |    total_timesteps | 900       |
# | train/             |           |
# |    actor_loss      | -2.87e+04 |
# |    critic_loss     | 1.01e+08  |
# |    ent_coef        | 1.25      |
# |    ent_coef_loss   | -27.6     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 799       |
# ----------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 29       |
# |    time_elapsed    | 60       |
# |    total_timesteps | 1800     |
# | train/             |          |
# |    actor_loss      | -1.8e+04 |
# |    critic_loss     | 3.19e+07 |
# |    ent_coef        | 1.63     |
# |    ent_coef_loss   | -60.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1699     |
# ---------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 21        |
# |    time_elapsed    | 125       |
# |    total_timesteps | 2700      |
# | train/             |           |
# |    actor_loss      | -1.38e+04 |
# |    critic_loss     | 2.04e+07  |
# |    ent_coef        | 2.13      |
# |    ent_coef_loss   | -93.4     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2599      |
# ----------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 19       |
# |    time_elapsed    | 188      |
# |    total_timesteps | 3600     |
# | train/             |          |
# |    actor_loss      | -5.5e+03 |
# |    critic_loss     | 7.71e+06 |
# |    ent_coef        | 2.78     |
# |    ent_coef_loss   | -127     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3499     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 17       |
# |    time_elapsed    | 250      |
# |    total_timesteps | 4500     |
# | train/             |          |
# |    actor_loss      | 2.63e+03 |
# |    critic_loss     | 1.78e+07 |
# |    ent_coef        | 3.64     |
# |    ent_coef_loss   | -160     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4399     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 17       |
# |    time_elapsed    | 312      |
# |    total_timesteps | 5400     |
# | train/             |          |
# |    actor_loss      | 5.77e+03 |
# |    critic_loss     | 4.29e+06 |
# |    ent_coef        | 4.77     |
# |    ent_coef_loss   | -193     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5299     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 16       |
# |    time_elapsed    | 374      |
# |    total_timesteps | 6300     |
# | train/             |          |
# |    actor_loss      | 9.52e+03 |
# |    critic_loss     | 8.43e+06 |
# |    ent_coef        | 6.25     |
# |    ent_coef_loss   | -227     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6199     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 16       |
# |    time_elapsed    | 435      |
# |    total_timesteps | 7200     |
# | train/             |          |
# |    actor_loss      | 1.62e+04 |
# |    critic_loss     | 6.88e+06 |
# |    ent_coef        | 8.19     |
# |    ent_coef_loss   | -261     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7099     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 16       |
# |    time_elapsed    | 502      |
# |    total_timesteps | 8100     |
# | train/             |          |
# |    actor_loss      | 2.13e+04 |
# |    critic_loss     | 4.66e+06 |
# |    ent_coef        | 10.7     |
# |    ent_coef_loss   | -294     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7999     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 15       |
# |    time_elapsed    | 570      |
# |    total_timesteps | 9000     |
# | train/             |          |
# |    actor_loss      | 3.3e+04  |
# |    critic_loss     | 1.15e+07 |
# |    ent_coef        | 14.1     |
# |    ent_coef_loss   | -327     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8899     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 15       |
# |    time_elapsed    | 631      |
# |    total_timesteps | 9900     |
# | train/             |          |
# |    actor_loss      | 3.99e+04 |
# |    critic_loss     | 6.1e+06  |
# |    ent_coef        | 18.4     |
# |    ent_coef_loss   | -361     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9799     |
# ---------------------------------
# Using cpu device
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 23       |
# |    time_elapsed    | 38       |
# |    total_timesteps | 900      |
# | train/             |          |
# |    actor_loss      | 1.72e+04 |
# |    critic_loss     | 3.14e+07 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 799      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 21       |
# |    time_elapsed    | 82       |
# |    total_timesteps | 1800     |
# | train/             |          |
# |    actor_loss      | 1.98e+04 |
# |    critic_loss     | 3.78e+07 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1699     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 20       |
# |    time_elapsed    | 130      |
# |    total_timesteps | 2700     |
# | train/             |          |
# |    actor_loss      | 1.81e+04 |
# |    critic_loss     | 1.49e+07 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2599     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 19       |
# |    time_elapsed    | 181      |
# |    total_timesteps | 3600     |
# | train/             |          |
# |    actor_loss      | 1.76e+04 |
# |    critic_loss     | 1.01e+07 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3499     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 19       |
# |    time_elapsed    | 234      |
# |    total_timesteps | 4500     |
# | train/             |          |
# |    actor_loss      | 1.96e+04 |
# |    critic_loss     | 2.16e+07 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4399     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 19       |
# |    time_elapsed    | 282      |
# |    total_timesteps | 5400     |
# | train/             |          |
# |    actor_loss      | 2.02e+04 |
# |    critic_loss     | 8.46e+06 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5299     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 19       |
# |    time_elapsed    | 328      |
# |    total_timesteps | 6300     |
# | train/             |          |
# |    actor_loss      | 1.91e+04 |
# |    critic_loss     | 8.69e+06 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6199     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 19       |
# |    time_elapsed    | 375      |
# |    total_timesteps | 7200     |
# | train/             |          |
# |    actor_loss      | 1.71e+04 |
# |    critic_loss     | 9.45e+06 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7099     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 19       |
# |    time_elapsed    | 421      |
# |    total_timesteps | 8100     |
# | train/             |          |
# |    actor_loss      | 1.87e+04 |
# |    critic_loss     | 1.03e+07 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7999     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 19       |
# |    time_elapsed    | 468      |
# |    total_timesteps | 9000     |
# | train/             |          |
# |    actor_loss      | 2.01e+04 |
# |    critic_loss     | 5.01e+06 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8899     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 19       |
# |    time_elapsed    | 517      |
# |    total_timesteps | 9900     |
# | train/             |          |
# |    actor_loss      | 2.01e+04 |
# |    critic_loss     | 2.76e+06 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9799     |
# ---------------------------------
# Testing PPO Agent...
# /home/zhiyuanzhang/miniconda3/envs/RLstock/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:243: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# Done testing PPO Agent!
# Testing A2C Agent...
# Done testing A2C Agent!
# Testing DDPG Agent...
# Done testing DDPG Agent!
# Testing Ensemble Agent...
# Done testing Ensemble Agent!
# Testing SAC Agent...
# Done testing SAC Agent!
# Testing TD3 Agent...
# Done testing TD3 Agent!
# --------------------------------------------------
# All agents tested!
# --------------------------------------------------

# %% [markdown]
# # 7. Testing Model - Ensemble + PPO + A2C + DDPG

# %%
# Create the environment using DummyVecEnv with test data
test_env = DummyVecEnv([lambda: StockTradingEnv(test_data)])

# 2. Test & visualize the agents on the test data
n_tests = 1000
test_agents = {
    'PPO Agent': ppo_agent,
    'A2C Agent': a2c_agent,
    'DDPG Agent': ddpg_agent,
    'Ensemble Agent': ensemble_agent,
    'SAC Agent': sac_agent,
    'TD3 Agent': td3_agent
}
test_and_visualize_agents(env, test_agents, test_data, n_tests=n_tests)

# 3. Compare the agents' performance on the test data ( returns, standard deviation, and sharpe ratio )
test_agents_metrics = [test_agent(env, agent, test_data, n_tests=n_tests, visualize=False) for agent in test_agents.values()]
compare_and_plot_agents(test_agents_metrics, list(test_agents.keys()))
# Out:
# Testing PPO Agent...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 14
#       5 n_tests = 1000
#       6 test_agents = {
#       7     'PPO Agent': ppo_agent,
#       8     'A2C Agent': a2c_agent,
#    (...)
#      12     'TD3 Agent': td3_agent
#      13 }
# ---> 14 test_and_visualize_agents(env, test_agents, test_data, n_tests=n_tests)
#      16 # 3. Compare the agents' performance on the test data ( returns, standard deviation, and sharpe ratio )
#      17 test_agents_metrics = [test_agent(env, agent, test_data, n_tests=n_tests, visualize=True) for agent in test_agents.values()]
#
# Cell In[30], line 5, in test_and_visualize_agents(env, agents, training_data, n_tests)
#       3 for agent_name, agent in agents.items():
#       4     print(f"Testing {agent_name}...")
# ----> 5     metrics[agent_name] = test_agent(env, agent, training_data, n_tests=n_tests, visualize=True)
#       6     print(f"Done testing {agent_name}!")
#       8 print('-'*50)
#
# Cell In[29], line 24, in test_agent(env, agent, stock_data, n_tests, visualize)
#      16 metrics = {
#      17     'steps': [],
#      18     'balances': [],
#      19     'net_worths': [],
#      20     'shares_held': {ticker: [] for ticker in stock_data.keys()}
#      21 }
#      23 # Reset the environment before starting the tests
# ---> 24 obs = env.reset()
#      26 for i in range(n_tests):
#      27     metrics['steps'].append(i)
#
# File ~/miniconda3/envs/RLstock/lib/python3.9/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:77, in DummyVecEnv.reset(self)
#      75 for env_idx in range(self.num_envs):
#      76     maybe_options = {"options": self._options[env_idx]} if self._options[env_idx] else {}
# ---> 77     obs, self.reset_infos[env_idx] = self.envs[env_idx].reset(seed=self._seeds[env_idx], **maybe_options)
#      78     self._save_obs(env_idx, obs)
#      79 # Seeds and options are only used once
#
# Cell In[24], line 57, in StockTradingEnv.reset(self, seed, options)
#      55 self.total_sales_value = {ticker: 0 for ticker in self.tickers}
#      56 self.current_step = 0
# ---> 57 return self._next_observation(), {}
#
# Cell In[24], line 71, in StockTradingEnv._next_observation(self)
#      69 # If the current step is less than the length of the DataFrame, add the price data for the current step
#      70 if self.current_step < len(df):
# ---> 71     frame[idx:idx+self.n_features] = df.iloc[self.current_step].values
#      72 # Otherwise, add the last price data available
#      73 elif len(df) > 0:
#
# ValueError: could not broadcast input array from shape (16,) into shape (10,)

# %%
test_agents_metrics
test_data
# 打印模型结构
print(ensemble_agent)
# Out:
# <__main__.SACAgent object at 0x7f5715c51100>
